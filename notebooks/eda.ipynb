# %% [markdown]
# # IBM HR Analytics Employee Attrition & Performance Exploratory Data Analysis 📊
#
# ## Importing dependencies

# %%
import sys
import os
import warnings

warnings.filterwarnings("ignore")
sys.path.append(os.path.abspath(os.path.join("..", "scripts", "utils")))

# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# Utils
import visualization as viz
from data_helpers import get_cols_names, print_cols_summary

# %%
DATA_PATH = os.path.join("..", "data", "raw", "hr_employee_attrition.csv")

# Setting parameters
pd.set_option("display.max_columns", 40)
pd.set_option("display.max_rows", 40)
pd.set_option("display.float_format", lambda x: f"{x:.2f}")

mpl.rc("axes", labelsize=14)
mpl.rc("xtick", labelsize=12)
mpl.rc("ytick", labelsize=12)

plt.style.use("ggplot")
sns.set_style("darkgrid", {"grid.color": ".8"})

# %% [markdown]
# ## EDA 📈
# ### Data Loading 🗃️

# %%
df = pd.read_csv(DATA_PATH)
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %% [markdown]
# ### Understanding the Dataset 💡

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
print(f"Samples: {df.shape[0]}")
print(f"Features: {df.shape[1]}")
print(f"Missing values: {df.isnull().sum().sum()}")
print(f"Duplicates count: {df.duplicated(keep=False).sum()}")
# Out:
# Samples: 1470
# Features: 35
# Missing values: 0
# Duplicates count: 0

# %%
df.describe()
# Out:
#           Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# count 1470.00    1470.00           1470.00    1470.00        1470.00
# mean    36.92     802.49              9.19       2.91           1.00
# std      9.14     403.51              8.11       1.02           0.00
# min     18.00     102.00              1.00       1.00           1.00
# 25%     30.00     465.00              2.00       2.00           1.00
# 50%     36.00     802.00              7.00       3.00           1.00
# 75%     43.00    1157.00             14.00       4.00           1.00
# max     60.00    1499.00             29.00       5.00           1.00
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count         1470.00                  1470.00     1470.00         1470.00
# mean          1024.87                     2.72       65.89            2.73
# std            602.02                     1.09       20.33            0.71
# ...

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
cat_cols, num_cols, num_but_cat_cols, cat_but_car_cols = get_cols_names(df)

print_cols_summary(df, cat_cols, num_cols, num_but_cat_cols, cat_but_car_cols)
# Out:
# Categorical columns (22) (including numeric-looking categorical columns): ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime', 'Education', 'EmployeeCount', 'EnvironmentSatisfaction', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'NumCompaniesWorked', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TrainingTimesLastYear', 'WorkLifeBalance']
#
# From them numeric-looking categorical columns (13): ['Education', 'EmployeeCount', 'EnvironmentSatisfaction', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'NumCompaniesWorked', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TrainingTimesLastYear', 'WorkLifeBalance']
#
# --------------------------------------------------
#
# ...

# %% [markdown]
# ### Data Visualisation 📊

# %%
target_col = "Attrition"

one_value_cols = [col for col in df.columns if df[col].nunique() <= 1]
one_value_cols
# Out:
# ['EmployeeCount', 'Over18', 'StandardHours']

# %% [markdown]
# #### Categorical Features Analysis
#
# In this section, we analyze the categorical features in the dataset by visualizing their distributions and examining their relationship with the target variable. For each categorical feature, we plot two visualizations side by side: one showing the **distribution of the feature** itself, and the other displaying **how the target variable is distributed across the categories**. Additionally, we include pie charts to illustrate the **distribution of each categorical feature separately for employees who stayed (No Attrition) and those who left (Yes Attrition)**.

# %%
def cat_by_target(col_name: str):
  """
  Visualizes the distribution of a categorical column by `Attrition` column.
  """
  if col_name not in df.columns:
    raise ValueError(f"Column '{col_name}' not found in DataFrame.")  
  
  cross_tab = pd.crosstab(df[col_name], df[target_col], normalize="columns") * 100
  pie_plot = cross_tab.plot(kind="pie", subplots=True, colormap="coolwarm", figsize=(12, 6), 
                            autopct="%1.1f%%", legend=False, fontsize=10, 
                            title=f"{col_name} Distribution Among Non-Attrition(Left) vs. Attrition(Right)", startangle=90)
  pie_plot.ravel()[0].set_ylabel("")
  pie_plot.ravel()[1].set_ylabel("")
  
  plt.tight_layout()

# %%
for col in cat_cols:
  if col != target_col and col not in one_value_cols: cat_by_target(col)
  fig = viz.plot_dual_distributions(df, target_col=target_col, col_name=col)
  viz.save_figure(fig, f"{col}_dual_distribution", "cat_features_analysis")  # Only saves the last figure
# Out:
# 📌Ratio of unique values in 'Attrition':
#            Ratio (%)
# Attrition
# No             83.88
# Yes            16.12
# --------------------------------------------------
# ✅ Figure saved.
#
#
# 📌Ratio of unique values in 'BusinessTravel':
#                    Ratio (%)
# BusinessTravel
# Travel_Rarely          70.95
# Travel_Frequently      18.84
# Non-Travel             10.20
# --------------------------------------------------
# ✅ Figure saved.
#
#
# 📌Ratio of unique values in 'Department':
#                         Ratio (%)
# Department
# Research & Development      65.37
# Sales                       30.34
# Human Resources              4.29
# --------------------------------------------------
# ✅ Figure saved.
#
#
# 📌Ratio of unique values in 'EducationField':
#                   Ratio (%)
# EducationField
# Life Sciences         41.22
# Medical               31.56
# Marketing             10.82
# Technical Degree       8.98
# Other                  5.58
# ...
